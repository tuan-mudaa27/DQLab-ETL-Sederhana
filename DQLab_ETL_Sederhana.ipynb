# %% [markdown]
# # **Koneksi Ke Google Big Query**

# %%
from google.colab import auth
from google.colab import data_table
from google.cloud import bigquery
from pandas_gbq import to_gbq
import pandas as pd
import numpy as np

# Proses autentikasi akun
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
from google.cloud import bigquery

# Buat BigQuery client
project_id = 'dqlab-469003'
bq_client = bigquery.Client(project = project_id)

# %% [markdown]
# ## **Proses Ekstraksi Data dari sumber (Extract)**

# %%
# %%bigquery data_transaksi --project {project_id}
#
# -- Tulis Query disini
# SELECT * FROM dqlab-468906.dqcommerce.tbl_transaction
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# %%bigquery data_produk --project {project_id}
#
# -- Tulis Query disini
# SELECT * FROM dqlab-468906.dqcommerce.tbl_product
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %%
# %%bigquery data_funnel --project {project_id}
#
# -- Tulis Query disini
# SELECT * FROM dqlab-468906.dqcommerce.tbl_funnel
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |

# %% [markdown]
# Setelah query dijalankan maka akan disimpan sebagai dataframe pandas

# %% [markdown]
# ## **Periksa Informasi Umum pada Data**

# %%
# Periksa informasi umum pada data
data_transaksi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   trx_id      829257 non-null  object
#  1   product_id  829262 non-null  object
#  2   trx_date    829262 non-null  Int64
#  3   trx_time    829262 non-null  dbtime
#  4   units       829251 non-null  Int64
# dtypes: Int64(2), dbtime(1), object(2)
# memory usage: 33.2+ MB

# %%
# Periksa informasi umum pada data
data_produk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        37 non-null     object
#  1   product_name      37 non-null     object
#  2   product_category  37 non-null     object
#  3   product_cost      37 non-null     object
#  4   product_price     37 non-null     object
# dtypes: object(5)
# memory usage: 1.6+ KB

# %%
# Periksa informasi umum pada data
data_funnel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15950 entries, 0 to 15949
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         15950 non-null  Int64
#  1   product_id   15950 non-null  object
#  2   purchase     15950 non-null  Int64
#  3   add_to_cart  15950 non-null  Int64
#  4   click        15950 non-null  Int64
#  5   view         15950 non-null  Int64
# dtypes: Int64(5), object(1)
# memory usage: 825.7+ KB

# %%
data_transaksi.sample(10)
# Out:
#              trx_id    product_id  trx_date  trx_time  units
# 260971  DQTrx496658  DQProduk-009  24022025  15:58:29      1
# 444498  DQTrx471401  DQProduk-019   5022025  16:01:55      1
# 288765  DQTrx502519  DQProduk-010  28022025  05:59:56      1
# 806600  DQTrx292976  DQProduk-031  27092024  18:23:50      3
# 50640   DQTrx184958  DQProduk-002  19062024  08:25:26      1
# 226115  DQTrx413694  DQProduk-008  27122024  14:38:31      1
# 544629  DQTrx432468  DQProduk-025   8012025  00:30:03      1
# 206929  DQTrx159807  DQProduk-008  29052024  11:42:13      1
# 138639  DQTrx235017  DQProduk-006   3082024  18:22:12      1
# 536491  DQTrx279553  DQProduk-025  16092024  06:07:53      1

# %% [markdown]
# ## **Proses Transformasi Data (Transform)**

# %%
data_transaksi['trx_date'] = data_transaksi['trx_date'].astype('str')

# %%
data_transaksi['trx_date'] = np.where(data_transaksi['trx_date'].str.len() == 7, '0' + data_transaksi['trx_date'], data_transaksi['trx_date'])

# %%
data_transaksi.sample(10)
# Out:
#              trx_id    product_id  trx_date  trx_time  units
# 177318  DQTrx183539  DQProduk-007  18062024  08:58:21      1
# 442163  DQTrx430211  DQProduk-019  07012025  01:11:17      1
# 439868  DQTrx379823  DQProduk-019  05122024  08:39:14      1
# 298364  DQTrx425826  DQProduk-011  04012025  07:23:07      1
# 220463  DQTrx333560  DQProduk-008  01112024  18:10:58      1
# 467803  DQTrx325530  DQProduk-020  25102024  10:25:46      1
# 101962  DQTrx753284  DQProduk-003  05082025  02:49:04      1
# 56742   DQTrx354145  DQProduk-002  17112024  10:02:09      1
# 475428  DQTrx393692  DQProduk-021  15122024  19:30:58      1
# 482347  DQTrx629505  DQProduk-021  19052025  19:03:07      1

# %%
data_transaksi['trx_date'] = pd.to_datetime(data_transaksi['trx_date'], format = '%d%m%Y')

# %%
data_transaksi.sample(10)
# Out:
#              trx_id    product_id   trx_date  trx_time  units
# 46627   DQTrx091995  DQProduk-002 2024-04-02  20:30:16      1
# 11374   DQTrx138819  DQProduk-001 2024-05-12  18:12:45      1
# 379301  DQTrx068094  DQProduk-017 2024-03-11  19:20:05      1
# 58496   DQTrx416948  DQProduk-002 2024-12-30  20:05:40      1
# 217168  DQTrx290440  DQProduk-008 2024-09-24  21:39:46      1
# 294672  DQTrx773438  DQProduk-010 2025-08-19  02:21:28      1
# 297195  DQTrx382920  DQProduk-011 2024-12-08  05:11:32      1
# 611924  DQTrx333570  DQProduk-030 2024-11-01  14:04:02      1
# 587639  DQTrx653828  DQProduk-027 2025-06-02  06:40:11      1
# 445361  DQTrx482776  DQProduk-019 2025-02-14  19:07:29      1

# %%
data_transaksi['trx_id'].isna().sum()
# Out:
# np.int64(5)

# %%
data_transaksi[data_transaksi['trx_id'].isna()]
# Out:
#        trx_id    product_id   trx_date  trx_time  units
# 106825   None  DQProduk-004 2024-01-01  14:43:09      1
# 193154   None  DQProduk-008 2024-01-01  09:27:56      1
# 468999   None  DQProduk-021 2024-01-01  13:16:09      1
# 499044   None  DQProduk-024 2024-01-01  06:32:49      1
# 571924   None  DQProduk-027 2024-01-01  04:15:36      1

# %%
data_transaksi.shape
# Out:
# (829262, 5)

# %%
data_transaksi = data_transaksi.dropna(subset = ['trx_id'])
data_transaksi.shape
# Out:
# (829257, 5)

# %%
data_transaksi[data_transaksi['units'].isna()]
# Out:
#          trx_id    product_id   trx_date  trx_time  units
# 0   DQTrx829214  DQProduk-016 2025-09-30  01:18:05   <NA>
# 1   DQTrx829166  DQProduk-017 2025-09-30  18:58:33   <NA>
# 2   DQTrx829118  DQProduk-018 2025-09-30  06:58:09   <NA>
# 3   DQTrx829186  DQProduk-019 2025-09-30  09:28:13   <NA>
# 4   DQTrx829212  DQProduk-019 2025-09-30  15:00:55   <NA>
# 5   DQTrx829213  DQProduk-019 2025-09-30  16:06:16   <NA>
# 6   DQTrx829235  DQProduk-019 2025-09-30  17:49:03   <NA>
# 7   DQTrx829167  DQProduk-024 2025-09-30  21:51:24   <NA>
# 8   DQTrx829168  DQProduk-025 2025-09-30  02:05:10   <NA>
# 9   DQTrx829254  DQProduk-025 2025-09-30  08:12:00   <NA>
# 10  DQTrx829169  DQProduk-028 2025-09-30  06:03:36   <NA>

# %%
data_transaksi['units'] = data_transaksi['units'].fillna(0)
data_transaksi['units'].isna().sum()
# Out:
# np.int64(0)

# %%
data_transaksi[data_transaksi['units'] == 0]
# Out:
#          trx_id    product_id   trx_date  trx_time  units
# 0   DQTrx829214  DQProduk-016 2025-09-30  01:18:05      0
# 1   DQTrx829166  DQProduk-017 2025-09-30  18:58:33      0
# 2   DQTrx829118  DQProduk-018 2025-09-30  06:58:09      0
# 3   DQTrx829186  DQProduk-019 2025-09-30  09:28:13      0
# 4   DQTrx829212  DQProduk-019 2025-09-30  15:00:55      0
# 5   DQTrx829213  DQProduk-019 2025-09-30  16:06:16      0
# 6   DQTrx829235  DQProduk-019 2025-09-30  17:49:03      0
# 7   DQTrx829167  DQProduk-024 2025-09-30  21:51:24      0
# 8   DQTrx829168  DQProduk-025 2025-09-30  02:05:10      0
# 9   DQTrx829254  DQProduk-025 2025-09-30  08:12:00      0
# 10  DQTrx829169  DQProduk-028 2025-09-30  06:03:36      0

# %%
data_transaksi.duplicated(subset='trx_id').sum()
# Out:
# np.int64(0)

# %%
data_transaksi.duplicated().sum()
# Out:
# np.int64(0)

# %%
data_produk
# Out:
#       product_id               product_name   product_category product_cost  \
# 0   DQProduk-009         Pulpen Metal DQLab         Alat Tulis   IDR 149850
# 1   DQProduk-003         Sticky Notes DQLab         Alat Tulis    IDR 29850
# 2   DQProduk-025        Tipe-X Roller DQLab         Alat Tulis    IDR 29850
# 3   DQProduk-016           Set Pulpen DQLab         Alat Tulis    IDR 44850
# 4   DQProduk-028        Penanda Warna DQLab         Alat Tulis    IDR 59850
# 5   DQProduk-004          Notebook A5 DQLab       Buku Catatan   IDR 149850
# 6   DQProduk-006      Earphone Kantor DQLab         Elektronik   IDR 104850
# 7   DQProduk-021     Kalkulator Besar DQLab         Elektronik   IDR 104850
# 8   DQProduk-032       Timbangan Mini DQLab         Elektronik   IDR 179850
# 9   DQProduk-013       Headset Kantor DQLab         Elektronik   IDR 224850
# 10  DQProduk-024          Label Maker DQLab         Elektronik   IDR 224850
# 11  DQProduk-030       Powerbank Logo DQLab         Elektronik   IDR 269850
# 12  DQProduk-026      Stempel + Tinta DQLab         Elektronik   IDR 314850
# 13  DQProduk-034         Speaker Mini DQLab         Elektronik   IDR 314850
# 14  DQProduk-018         Printer Mini DQLab         Elektronik   IDR 524850
# 15  DQProduk-019         Kertas Warna DQLab     Kertas & Cetak   IDR 209850
# 16  DQProduk-008           Kartu Nama DQLab     Kertas & Cetak    IDR 59850
# 17  DQProduk-035         Kartu Ucapan DQLab     Kertas & Cetak    IDR 59850
# 18  DQProduk-035         Kartu Ucapan DQLab     Kertas & Cetak    IDR 59850
# 19  DQProduk-014           Label Nama DQLab     Kertas & Cetak    IDR 89850
# 20  DQProduk-005         Dompet Kartu DQLab        Merchandise   IDR 119850
# 21  DQProduk-029      Gantungan Kunci DQLab        Merchandise   IDR 134850
# 22  DQProduk-001          Buku Agenda DQLab        Merchandise   IDR 149850
# 23  DQProduk-002          Termos Logo DQLab        Merchandise   IDR 149850
# 24  DQProduk-033         Tumbler Logo DQLab        Merchandise   IDR 164850
# 25  DQProduk-007          Botol Minum DQLab        Merchandise   IDR 179850
# 26  DQProduk-017  Set Tulis Eksekutif DQLab        Merchandise   IDR 209850
# 27  DQProduk-015      Mousepad Custom DQLab        Merchandise    IDR 59850
# 28  DQProduk-015      Mousepad Custom DQLab        Merchandise    IDR 59850
# 29  DQProduk-023         Tempat Kartu DQLab        Merchandise    IDR 74850
# 30  DQProduk-012             Rak Meja DQLab         Organisasi   IDR 134850
# 31  DQProduk-010      Kotak Serbaguna DQLab         Organisasi   IDR 164850
# 32  DQProduk-022        Map Eksklusif DQLab         Organisasi   IDR 209850
# 33  DQProduk-031      Lakban + Cutter DQLab         Pengemasan   IDR 119850
# 34  DQProduk-020           Papan Klip DQLab  Perlengkapan Meja   IDR 134850
# 35  DQProduk-011   Bingkai Sertifikat DQLab  Perlengkapan Meja   IDR 164850
# 36  DQProduk-027        Staples + Box DQLab  Perlengkapan Meja    IDR 59850
#
#    product_price
# 0     IDR 164850
# 1      IDR 59850
# 2      IDR 44850
# 3     IDR 149850
# 4     IDR 164850
# 5     IDR 194850
# 6     IDR 224850
# 7     IDR 149850
# 8     IDR 224850
# 9     IDR 314850
# 10    IDR 299850
# 11    IDR 299850
# 12    IDR 374850
# 13    IDR 389850
# 14    IDR 599850
# 15    IDR 239850
# 16    IDR 104850
# 17    IDR 119850
# 18    IDR 119850
# 19    IDR 164850
# 20    IDR 149850
# 21    IDR 299850
# 22    IDR 239850
# 23    IDR 194850
# 24    IDR 194850
# 25    IDR 239850
# 26    IDR 299850
# 27     IDR 89850
# 28     IDR 89850
# 29    IDR 149850
# 30    IDR 179850
# 31    IDR 224850
# 32    IDR 299850
# 33    IDR 134850
# 34    IDR 374850
# 35    IDR 314850
# 36     IDR 74850

# %%
for col in ['product_cost', 'product_price']:
  data_produk[col] = data_produk[col].str.replace('IDR ', '')
  data_produk[col] = data_produk[col].astype('int64')

data_produk
# Out:
#       product_id               product_name   product_category  product_cost  \
# 0   DQProduk-009         Pulpen Metal DQLab         Alat Tulis        149850
# 1   DQProduk-003         Sticky Notes DQLab         Alat Tulis         29850
# 2   DQProduk-025        Tipe-X Roller DQLab         Alat Tulis         29850
# 3   DQProduk-016           Set Pulpen DQLab         Alat Tulis         44850
# 4   DQProduk-028        Penanda Warna DQLab         Alat Tulis         59850
# 5   DQProduk-004          Notebook A5 DQLab       Buku Catatan        149850
# 6   DQProduk-006      Earphone Kantor DQLab         Elektronik        104850
# 7   DQProduk-021     Kalkulator Besar DQLab         Elektronik        104850
# 8   DQProduk-032       Timbangan Mini DQLab         Elektronik        179850
# 9   DQProduk-013       Headset Kantor DQLab         Elektronik        224850
# 10  DQProduk-024          Label Maker DQLab         Elektronik        224850
# 11  DQProduk-030       Powerbank Logo DQLab         Elektronik        269850
# 12  DQProduk-026      Stempel + Tinta DQLab         Elektronik        314850
# 13  DQProduk-034         Speaker Mini DQLab         Elektronik        314850
# 14  DQProduk-018         Printer Mini DQLab         Elektronik        524850
# 15  DQProduk-019         Kertas Warna DQLab     Kertas & Cetak        209850
# 16  DQProduk-008           Kartu Nama DQLab     Kertas & Cetak         59850
# 17  DQProduk-035         Kartu Ucapan DQLab     Kertas & Cetak         59850
# 18  DQProduk-035         Kartu Ucapan DQLab     Kertas & Cetak         59850
# 19  DQProduk-014           Label Nama DQLab     Kertas & Cetak         89850
# 20  DQProduk-005         Dompet Kartu DQLab        Merchandise        119850
# 21  DQProduk-029      Gantungan Kunci DQLab        Merchandise        134850
# 22  DQProduk-001          Buku Agenda DQLab        Merchandise        149850
# 23  DQProduk-002          Termos Logo DQLab        Merchandise        149850
# 24  DQProduk-033         Tumbler Logo DQLab        Merchandise        164850
# 25  DQProduk-007          Botol Minum DQLab        Merchandise        179850
# 26  DQProduk-017  Set Tulis Eksekutif DQLab        Merchandise        209850
# 27  DQProduk-015      Mousepad Custom DQLab        Merchandise         59850
# 28  DQProduk-015      Mousepad Custom DQLab        Merchandise         59850
# 29  DQProduk-023         Tempat Kartu DQLab        Merchandise         74850
# 30  DQProduk-012             Rak Meja DQLab         Organisasi        134850
# 31  DQProduk-010      Kotak Serbaguna DQLab         Organisasi        164850
# 32  DQProduk-022        Map Eksklusif DQLab         Organisasi        209850
# 33  DQProduk-031      Lakban + Cutter DQLab         Pengemasan        119850
# 34  DQProduk-020           Papan Klip DQLab  Perlengkapan Meja        134850
# 35  DQProduk-011   Bingkai Sertifikat DQLab  Perlengkapan Meja        164850
# 36  DQProduk-027        Staples + Box DQLab  Perlengkapan Meja         59850
#
#     product_price
# 0          164850
# 1           59850
# 2           44850
# 3          149850
# 4          164850
# 5          194850
# 6          224850
# 7          149850
# 8          224850
# 9          314850
# 10         299850
# 11         299850
# 12         374850
# 13         389850
# 14         599850
# 15         239850
# 16         104850
# 17         119850
# 18         119850
# 19         164850
# 20         149850
# 21         299850
# 22         239850
# 23         194850
# 24         194850
# 25         239850
# 26         299850
# 27          89850
# 28          89850
# 29         149850
# 30         179850
# 31         224850
# 32         299850
# 33         134850
# 34         374850
# 35         314850
# 36          74850

# %%
data_produk.duplicated().sum()
# Out:
# np.int64(2)

# %%
data_produk[data_produk.duplicated(subset='product_id', keep=False)]
# Out:
#       product_id           product_name product_category  product_cost  \
# 17  DQProduk-035     Kartu Ucapan DQLab   Kertas & Cetak         59850
# 18  DQProduk-035     Kartu Ucapan DQLab   Kertas & Cetak         59850
# 27  DQProduk-015  Mousepad Custom DQLab      Merchandise         59850
# 28  DQProduk-015  Mousepad Custom DQLab      Merchandise         59850
#
#     product_price
# 17         119850
# 18         119850
# 27          89850
# 28          89850

# %%
data_produk.shape
# Out:
# (37, 5)

# %%
data_produk = data_produk.drop_duplicates(subset='product_id', keep='first')
data_produk.shape
# Out:
# (35, 5)

# %%
data_integrasi = pd.merge(data_transaksi, data_produk, on='product_id', how='left')
data_integrasi.sample(10)
# Out:
#              trx_id    product_id   trx_date  trx_time  units  \
# 312082  DQTrx758224  DQProduk-012 2025-08-09  03:29:12      1
# 398249  DQTrx030306  DQProduk-018 2024-02-01  17:48:48      1
# 568829  DQTrx344686  DQProduk-026 2024-11-09  21:46:20      1
# 98749   DQTrx690544  DQProduk-003 2025-06-26  10:48:57      1
# 283014  DQTrx268683  DQProduk-010 2024-09-04  07:30:14      1
# 259528  DQTrx454306  DQProduk-009 2025-01-25  20:04:19      1
# 113791  DQTrx639569  DQProduk-005 2025-05-25  09:37:29      1
# 231152  DQTrx475823  DQProduk-008 2025-02-09  12:41:35      1
# 249658  DQTrx782886  DQProduk-008 2025-08-27  14:33:47      1
# 598475  DQTrx003567  DQProduk-030 2024-01-05  20:06:21      1
#
#                  product_name product_category  product_cost  product_price
# 312082         Rak Meja DQLab       Organisasi        134850         179850
# 398249     Printer Mini DQLab       Elektronik        524850         599850
# 568829  Stempel + Tinta DQLab       Elektronik        314850         374850
# 98749      Sticky Notes DQLab       Alat Tulis         29850          59850
# 283014  Kotak Serbaguna DQLab       Organisasi        164850         224850
# 259528     Pulpen Metal DQLab       Alat Tulis        149850         164850
# 113791     Dompet Kartu DQLab      Merchandise        119850         149850
# 231152       Kartu Nama DQLab   Kertas & Cetak         59850         104850
# 249658       Kartu Nama DQLab   Kertas & Cetak         59850         104850
# 598475   Powerbank Logo DQLab       Elektronik        269850         299850

# %% [markdown]
# ## **Proses Simpan Data (Load)**

# %%
import pandas as pd

# Upload ke BigQuery - tabel belum ada
to_gbq(
    data_integrasi,
    destination_table = 'tbl_dwh_dqcommerce.tbl_integrasi',
    project_id = project_id,
    if_exists = 'fail'
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 2235.77it/s]

# %% [markdown]
# ---

# %% [markdown]
# ### Overview Total Penjualan Periode Data Tiap Bulan

# %%
data_transaksi['month_year'] = data_transaksi['trx_date'].dt.strftime('%Y-%m')
data_transaksi.head()
# Out:
#         trx_id    product_id   trx_date  trx_time  units month_year
# 0  DQTrx829214  DQProduk-016 2025-09-30  01:18:05      0    2025-09
# 1  DQTrx829166  DQProduk-017 2025-09-30  18:58:33      0    2025-09
# 2  DQTrx829118  DQProduk-018 2025-09-30  06:58:09      0    2025-09
# 3  DQTrx829186  DQProduk-019 2025-09-30  09:28:13      0    2025-09
# 4  DQTrx829212  DQProduk-019 2025-09-30  15:00:55      0    2025-09

# %%
penjualan_bulanan = data_transaksi.groupby(['month_year'], as_index = False).agg(total = ('units', 'sum'))
penjualan_bulanan.head()
# Out:
#   month_year  total
# 0    2024-01  38004
# 1    2024-02  36935
# 2    2024-03  39981
# 3    2024-04  47102
# 4    2024-05  46910

# %%
import plotly.express as px

# Membuat line chart
fig = px.line(
    penjualan_bulanan,
    x="month_year",
    y="total",
    title="<b>Grafik Total Penjualan Bulanan DQ-Commerce</b>",
    color_discrete_sequence = ['#39074E'],
    markers=False)

"""
fig.add_vrect(
    x0="2025-03", x1="2025-09",
    fillcolor="#E73c35",
    opacity=0.5,
    layer="below",
    line_width=0,
    #annotation_text="Tahun 2025",
    #annotation_position="top "
)
"""

fig.update_layout(
    height = 450,
    width = 1100,
    plot_bgcolor = 'rgba(0, 0, 0, 0)',
    yaxis = dict(
        showline = True,
        linewidth = 1,
        color = '#544018',
        linecolor = '#544018',
        showgrid=False,
    ),
    xaxis = dict(
        title = '',
        showline = True,
        linewidth = 1,
        color = '#544018',
        linecolor = '#544018',
        showgrid=False,
    ),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e231ad7e-5254-4e8f-aaaf-b9dc3f923f80" class="plotly-graph-div" style="height:450px; width:1100px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e231ad7e-5254-4e8f-aaaf-b9dc3f923f80")) {                    Plotly.newPlot(                        "e231ad7e-5254-4e8f-aaaf-b9dc3f923f80",                        [{"hovertemplate":"month_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#39074E","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"xaxis":"x","y":[38004,36935,39981,47102,46910,47178,46177,39927,42196,47861,51185,66031,56478,54581,69336,65593,63851,64275,63614,51193,52141],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar": ...

# %%
penjualan_per_produk = data_transaksi.groupby(['month_year', 'product_id'], as_index = False).agg(total = ('units', 'sum'))
penjualan_per_produk.head()
# Out:
#   month_year    product_id  total
# 0    2024-01  DQProduk-001   3441
# 1    2024-01  DQProduk-002   1513
# 2    2024-01  DQProduk-003     76
# 3    2024-01  DQProduk-004    165
# 4    2024-01  DQProduk-005    276

# %%
import plotly.express as px

# Membuat line chart
fig = px.line(
    penjualan_per_produk, #[penjualan['month_year'] >= '2025-01'],
    x="month_year",
    y="total",
    color="product_id",
    title="<b>Grafik Total Penjualan Bulanan DQ-Commerce Per Produk</b>",
    markers=True
)

fig.update_layout(
    height = 550,
    width = 1200,
    plot_bgcolor = 'rgba(0, 0, 0, 0)',
    yaxis = dict(
        showline = True,
        linewidth = 1,
        color = '#544018',
        linecolor = '#544018',
        showgrid=False,
    ),
    xaxis = dict(
        title = '',
        showline = True,
        linewidth = 1,
        color = '#544018',
        linecolor = '#544018',
        showgrid=False,
    ),
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b64c5073-6593-49eb-835d-d0d7fd695aef" class="plotly-graph-div" style="height:550px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b64c5073-6593-49eb-835d-d0d7fd695aef")) {                    Plotly.newPlot(                        "b64c5073-6593-49eb-835d-d0d7fd695aef",                        [{"hovertemplate":"product_id=DQProduk-001\u003cbr\u003emonth_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DQProduk-001","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DQProduk-001","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"xaxis":"x","y":[3441,3145,3624,3705,3588,3813,3152,2703,2325,2523,2455,2561,2274,2039,3261,2688,2680,3211,1528,1580,1662],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_id=DQProduk-002\u003cbr\u003emonth_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DQProduk-002","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DQProduk-002","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"xaxis":"x","y":[1513,1912,1903,2165,2148,2161,2124,1427,1250,1972,1985,1720,1439,1424,2002,1707,2067,2017,2186,1937,2030],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_id=DQProduk-003\u003cbr\u003emonth_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DQProduk-003","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DQProduk-003","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"xaxis":"x","y":[76,18,20,969,4248,7574,8656,8870,7759,8191,10061,8015,6356,6525,5380,3692,5253],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_id=DQProduk-004\u003cbr\u003emonth_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DQProduk-004","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DQProduk-004","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"xaxis":"x","y":[165,37,17,19,5,174,218,231,167,165,263,470,301,173,224,192,203,193,228,217,166],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_id=DQProduk-005\u003cbr\u003emonth_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DQProduk-005","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"DQProduk-005","orientation":"v","showlegend":true,"x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"xaxis":"x","y":[276,203,167,290,166,249,216,213,158,115,137,330,287,185,291,191,181,190,256,193,177],"yaxis":"y","type":"scatter"},{"hovertemplate":"product_id=DQProduk-006\u003cbr\u003emonth_year=%{x}\u003cbr\u003etotal=%{y}\u003cextra\u003e\u003c ...

# %%
import plotly.graph_objects as go

highlight_product = ['DQProduk-003', 'DQProduk-019', 'DQProduk-025', 'DQProduk-018', 'DQProduk-031']

fig = go.Figure()

# Loop setiap produk
for product in penjualan_per_produk['product_id'].unique():
    df_product = penjualan_per_produk[penjualan_per_produk['product_id'] == product]

    # Tentukan properti styling
    if product in highlight_product:
        line_color = 'purple'
        line_width = 3
    else:
        line_color = 'lightgray'
        line_width = 1.2

    # Tambahkan trace
    fig.add_trace(go.Scatter(
        x=df_product['month_year'],
        y=df_product['total'],
        mode='lines+markers',
        name=product,
        line=dict(
            width=line_width,
            color=line_color
        )
    ))

# Layout styling
fig.update_layout(
    title="<b>Grafik Total Penjualan Bulanan DQ-Commerce Per Produk</b>",
    height=550,
    width=1200,
    plot_bgcolor='rgba(0, 0, 0, 0)',
    xaxis=dict(
        showline=True,
        linewidth=1,
        color='#544018',
        linecolor='#544018',
        title='',
        showgrid=False,
    ),
    yaxis=dict(
        showline=True,
        linewidth=1,
        color='#544018',
        linecolor='#544018',
        showgrid=False,
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="16841693-9bd6-4d7a-9efb-cf0fc1e586d6" class="plotly-graph-div" style="height:550px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16841693-9bd6-4d7a-9efb-cf0fc1e586d6")) {                    Plotly.newPlot(                        "16841693-9bd6-4d7a-9efb-cf0fc1e586d6",                        [{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-001","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[3441,3145,3624,3705,3588,3813,3152,2703,2325,2523,2455,2561,2274,2039,3261,2688,2680,3211,1528,1580,1662],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-002","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[1513,1912,1903,2165,2148,2161,2124,1427,1250,1972,1985,1720,1439,1424,2002,1707,2067,2017,2186,1937,2030],"type":"scatter"},{"line":{"color":"purple","width":3},"mode":"lines+markers","name":"DQProduk-003","x":["2024-01","2024-02","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[76,18,20,969,4248,7574,8656,8870,7759,8191,10061,8015,6356,6525,5380,3692,5253],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-004","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[165,37,17,19,5,174,218,231,167,165,263,470,301,173,224,192,203,193,228,217,166],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-005","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[276,203,167,290,166,249,216,213,158,115,137,330,287,185,291,191,181,190,256,193,177],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-006","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[8110,7627,7843,7267,6974,6506,6511,6368,4931,4713,4284,4078,3666,3301,3660,3369,2795,3069,3537,3165,2594],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-007","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[1747,1727,1781,1877,1612,2174,2033,1497,1679,1522,1679,2012,1333,947,1150,914,1270,1117,1163,1332,1022],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-008","x":["2024-01","2024-02","2024-03","2024-04","2024-05","2024-06","2024-07","2024-08","2024-09","2024-10","2024-11","2024-12","2025-01","2025-02","2025-03","2025-04","2025-05","2025-06","2025-07","2025-08","2025-09"],"y":[4412,3633,3507,4777,3761,4117,4283,3336,3210,3584,3375,5554,4890,3920,4944,4514,3698,3577,4223,3745,2973],"type":"scatter"},{"line":{"color":"lightgray","width":1.2},"mode":"lines+markers","name":"DQProduk-009","x":["2024- ...
